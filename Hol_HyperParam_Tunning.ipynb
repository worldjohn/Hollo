# %% [markdown]
# ### Importing Libarary

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np
import time

# %% [markdown]
# ### Data Preparation

# %%
transform = transforms.Compose(
            [transforms.ToTensor(),
             transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10('./data', train=True,
                                        download=True, transform=transform)
trainset, valset = torch.utils.data.random_split(trainset, [40000, 10000])
testset =  torchvision.datasets.CIFAR10('./data', train=False,
                                        download=True, transform=transform)
partition = {'train': trainset, 'val': valset, 'test': testset}
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ### Model Architecture

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, hid_dim, n_layer, act, dropout, use_bn, use_xavier):
        super(MLP, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.hid_dim = hid_dim
        self.n_layer = n_layer
        self.act = act
        self.dropout = dropout
        self.use_bn = use_bn
        self.use_xavier = use_xavier

        # ===== Create Linear Layers ===== #
        self.fc1 = nn.Linear(self.in_dim, self.hid_dim)
        self.linears = nn.ModuleList()
        self.bns = nn.ModuleList()
        for i in range(self.n_layer-1):
            self.linears.append(nn.Linear(self.hid_dim, self.hid_dim))
            if self.use_bn:
                self.bns.append(nn.BatchNorm1d(self.hid_dim))
        self.fc2 = nn.Linear(self.hid_dim, self.out_dim)

        # ===== Create Activation Function ===== #
        if self.act == 'relu':
            self.act = nn.ReLU()
        elif self.act == 'tanh':
            self.act = nn.Tanh()
        elif self.act == 'sigmoid':
            self.act = nn.Sigmoid()
        else:
            raise ValueError('no valid activation function selected.')

        # ===== Create Regularization Layer and Initialize weights ===== #
        self.dropout = nn.Dropout(self.dropout)
        if self.use_xavier:
            self.xavier_init()
        
    def xavier_init(self):
        for linear in self.linears:
            nn.init.xavier_normal_(linear.weight)
            linear.bias.data.fill_(0.01)
    
    def forward(self, x):
        x = self.act(self.fc1(x))
        for i in range(len(self.linears)):
            x = self.act(self.linears[i](x))
            x = self.bns[i](x)
            x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Train, Validate, Test and Experiment Function

# %%
def train(net, partition, optimizer, criterion, args):
    trainloader = torch.utils.data.DataLoader(partition['train'],
                                              batch_size=args.train_batch_size,
                                              shuffle=True,
                                              num_workers=2)
    net.train()
    correct = 0
    total = 0
    train_loss = 0.0
    for data in trainloader:
        optimizer.zero_grad()

        inputs, labels = data
        inputs = inputs.view(-1, 3*32*32)
        inputs = inputs.to(args.device)
        labels = labels.to(args.device)
        outputs = net(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)  # _는 max의 value, predicted는 max의 index
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = train_loss / len(trainloader)
    train_acc = 100 * correct / total
    return net, train_loss, train_acc

# %%
def validate(net, partition, criterion, args):
    valloader = torch.utils.data.DataLoader(partition['val'],
                                              batch_size=args.test_batch_size,
                                              shuffle=False,
                                              num_workers=2)
    net.eval()
    correct = 0
    total = 0
    val_loss = 0.0
    with torch.no_grad():
        for data in valloader:
            images, labels = data
            images = images.view(-1, 3*32*32)
            images = images.to(args.device)
            labels = labels.to(args.device)
            outputs = net(images)

            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)  # _는 max의 value, predicted는 max의 index
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        val_loss = val_loss / len(valloader)
        val_acc = 100 * correct / total
    return val_loss, val_acc

# %%
def test(net, partition, args):
    testloader = torch.utils.data.DataLoader(partition['test'],
                                              batch_size=args.test_batch_size,
                                              shuffle=False,
                                              num_workers=2)
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.view(-1, 3*32*32)
            images = images.to(args.device)
            labels = labels.to(args.device)
            outputs = net(images)

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        test_acc = 100 * correct / total
    return test_acc

# %%
def experiment(partition, args):
    net = MLP(args.in_dim, args.out_dim, args.hid_dim, args.n_layer, args.act, args.dropout, args.use_bn, args.use_xavier)
    net = net.to(args.device)

    criterion = nn.CrossEntropyLoss()
    if args.optim == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('Invalid optimizer choice')
    
    for epoch in range(args.epoch):
        ts = time.time()
        net, train_loss, train_acc = train(net, partition, optimizer, criterion, args)
        val_loss, val_acc          = validate(net, partition, criterion, args)
        te = time.time()
        print('Epoch {:3d}  Accuracy(train/val): {:2.2f}%/{:2.2f}%  Loss(train/val): {:2.2f}/{:2.2f}  Took {:2.2f} sec'.format(epoch+1, train_acc, val_acc, train_loss, val_loss, te-ts))

    test_acc = test(net, partition, args)
    return train_loss, val_loss, train_acc, val_acc, test_acc

# %% [markdown]
# ### Experiment

# %%
# ===== Random Seed ===== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")

# ===== Device Allocation ===== #
args.device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# ===== Model Capacity ===== #
args.in_dim = 3*32*32
args.out_dim = 10
args.hid_dim = 100
args.act = 'relu'

# ===== Regularization ===== #
args.dropout = 0.2
args.use_bn = True
args.l2 = 0.00001
args.use_xavier = True

# ===== Optimizer & Training ===== #
args.optim = 'Adam'  # 'SGD', 'RMSprop', 'Adam'
args.lr = 0.001
args.epoch = 10

args.train_batch_size = 256
args.test_batch_size = 1024

# ===== Experiment Variable ===== #
list_n_layer = [3, 4, 5]
list_hid_dim = [300, 500, 700]

for n_layer in list_n_layer:
    for hid_dim in list_hid_dim:
        setattr(args, 'n_layer', n_layer)
        setattr(args, 'hid_dim', hid_dim)
        print(args)
        train_loss, val_loss, _, _, test_acc = experiment(partition, args)
        print('---'*20)
        print('Test Accuracy: {:2.3f}%   Train Loss: {:2.5f}  Val Loss: {:2.5f}'.format(test_acc, train_loss, val_loss))
        print('---'*20)
# Out:
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=300, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 37.90%/45.61%  Loss(train/val): 1.74/1.54  Took 16.67 sec
# Epoch   2  Accuracy(train/val): 46.25%/48.97%  Loss(train/val): 1.50/1.44  Took 16.16 sec
# Epoch   3  Accuracy(train/val): 50.76%/49.12%  Loss(train/val): 1.38/1.41  Took 16.87 sec
# Epoch   4  Accuracy(train/val): 53.22%/51.91%  Loss(train/val): 1.31/1.36  Took 16.33 sec
# Epoch   5  Accuracy(train/val): 55.67%/52.27%  Loss(train/val): 1.23/1.35  Took 17.95 sec
# Epoch   6  Accuracy(train/val): 58.03%/52.80%  Loss(train/val): 1.17/1.35  Took 16.34 sec
# Epoch   7  Accuracy(train/val): 59.84%/52.90%  Loss(train/val): 1.12/1.35  Took 16.31 sec
# Epoch   8  Accuracy(train/val): 61.70%/53.97%  Loss(train/val): 1.08/1.33  Took 16.43 sec
# Epoch   9  Accuracy(train/val): 63.57%/54.06%  Loss(train/val): 1.01/1.35  Took 16.38 sec
# Epoch  10  Accuracy(train/val): 65.28%/54.23%  Loss(train/val): 0.98/1.35  Took 16.42 sec
# ------------------------------------------------------------
# Test Accuracy: 54.730%   Train Loss: 0.97642  Val Loss: 1.35431
# ------------------------------------------------------------
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=500, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 38.39%/44.88%  Loss(train/val): 1.73/1.54  Took 19.77 sec
# Epoch   2  Accuracy(train/val): 46.55%/48.89%  Loss(train/val): 1.49/1.44  Took 19.78 sec
# Epoch   3  Accuracy(train/val): 50.73%/50.32%  Loss(train/val): 1.37/1.39  Took 19.79 sec
# Epoch   4  Accuracy(train/val): 54.30%/51.29%  Loss(train/val): 1.28/1.37  Took 21.33 sec
# Epoch   5  Accuracy(train/val): 56.50%/52.82%  Loss(train/val): 1.21/1.34  Took 19.88 sec
# Epoch   6  Accuracy(train/val): 58.91%/53.31%  Loss(train/val): 1.15/1.33  Took 19.99 sec
# Epoch   7  Accuracy(train/val): 61.21%/53.92%  Loss(train/val): 1.08/1.33  Took 19.80 sec
# Epoch   8  Accuracy(train/val): 63.08%/54.20%  Loss(train/val): 1.03/1.33  Took 19.84 sec
# Epoch   9  Accuracy(train/val): 64.79%/54.13%  Loss(train/val): 0.98/1.34  Took 19.76 sec
# Epoch  10  Accuracy(train/val): 67.31%/54.60%  Loss(train/val): 0.91/1.36  Took 19.72 sec
# ------------------------------------------------------------
# Test Accuracy: 54.660%   Train Loss: 0.91404  Val Loss: 1.36059
# ------------------------------------------------------------
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=700, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 38.62%/44.31%  Loss(train/val): 1.72/1.56  Took 26.63 sec
# Epoch   2  Accuracy(train/val): 47.49%/48.69%  Loss(train/val): 1.48/1.43  Took 25.35 sec
# Epoch   3  Accuracy(train/val): 51.47%/50.44%  Loss(train/val): 1.36/1.41  Took 25.30 sec
# Epoch   4  Accuracy(train/val): 54.49%/52.47%  Loss(train/val): 1.27/1.35  Took 25.42 sec
# Epoch   5  Accuracy(train/val): 57.19%/52.54%  Loss(train/val): 1.20/1.35  Took 25.38 sec
# Epoch   6  Accuracy(train/val): 59.65%/52.41%  Loss(train/val): 1.13/1.37  Took 25.33 sec
# Epoch   7  Accuracy(train/val): 61.55%/53.48%  Loss(train/val): 1.08/1.35  Took 26.66 sec
# Epoch   8  Accuracy(train/val): 63.94%/53.55%  Loss(train/val): 1.01/1.35  Took 25.34 sec
# Epoch   9  Accuracy(train/val): 66.56%/53.42%  Loss(train/val): 0.94/1.40  Took 25.34 sec
# Epoch  10  Accuracy(train/val): 68.15%/53.62%  Loss(train/val): 0.89/1.40  Took 25.37 sec
# ------------------------------------------------------------
# Test Accuracy: 54.060%   Train Loss: 0.88654  Val Loss: 1.40060
# ------------------------------------------------------------
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=300, in_dim=3072, l2=1e-05, lr=0.001, n_layer=4, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 36.45%/44.69%  Loss(train/val): 1.78/1.56  Took 17.17 sec
# Epoch   2  Accuracy(train/val): 45.06%/48.37%  Loss(train/val): 1.53/1.45  Took 16.91 sec
# Epoch   3  Accuracy(train/val): 49.33%/49.79%  Loss(train/val): 1.42/1.41  Took 17.04 sec
# Epoch   4  Accuracy(train/val): 51.59%/50.33%  Loss(train/val): 1.35/1.39  Took 18.53 sec
# Epoch   5  Accuracy(train/val): 54.66%/51.15%  Loss(train/val): 1.27/1.38  Took 17.02 sec
# Epoch   6  Accuracy(train/val): 56.58%/52.82%  Loss(train/val): 1.22/1.34  Took 17.16 sec
# Epoch   7  Accuracy(train/val): 58.60%/53.40%  Loss(train/val): 1.16/1.33  Took 17.08 sec
# Epoch   8  Accuracy(train/val): 60.15%/53.73%  Loss(train/val): 1.12/1.34  Took 17.17 sec
# Epoch   9  Accuracy(train/val): 61.87%/53.96%  Loss(train/val): 1.07/1.34  Took 16.90 sec
# Epoch  10  Accuracy(train/val): 63.29%/53.79%  Loss(train/val): 1.03/1.37  Took 17.09 sec
# ------------------------------------------------------------
# Test Accuracy: 53.520%   Train Loss: 1.03210  Val Loss: 1.37012
# ------------------------------------------------------------
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=500, in_dim=3072, l2=1e-05, lr=0.001, n_layer=4, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 36.98%/43.89%  Loss(train/val): 1.76/1.55  Took 21.92 sec
# Epoch   2  Accuracy(train/val): 45.87%/47.43%  Loss(train/val): 1.51/1.47  Took 23.46 sec
# Epoch   3  Accuracy(train/val): 50.20%/49.33%  Loss(train/val): 1.40/1.42  Took 22.10 sec
# Epoch   4  Accuracy(train/val): 53.26%/51.51%  Loss(train/val): 1.31/1.38  Took 21.96 sec
# Epoch   5  Accuracy(train/val): 55.73%/52.21%  Loss(train/val): 1.24/1.37  Took 22.02 sec
# Epoch   6  Accuracy(train/val): 58.42%/52.76%  Loss(train/val): 1.17/1.33  Took 21.86 sec
# Epoch   7  Accuracy(train/val): 60.47%/54.33%  Loss(train/val): 1.11/1.32  Took 24.19 sec
# Epoch   8  Accuracy(train/val): 62.01%/53.49%  Loss(train/val): 1.06/1.35  Took 23.75 sec
# Epoch   9  Accuracy(train/val): 63.33%/54.05%  Loss(train/val): 1.02/1.36  Took 21.84 sec
# Epoch  10  Accuracy(train/val): 64.71%/54.13%  Loss(train/val): 0.98/1.35  Took 21.59 sec
# ------------------------------------------------------------
# Test Accuracy: 53.880%   Train Loss: 0.98330  Val Loss: 1.35026
# ------------------------------------------------------------
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=700, in_dim=3072, l2=1e-05, lr=0.001, n_layer=4, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 36.71%/44.24%  Loss(train/val): 1.77/1.57  Took 28.43 sec
# Epoch   2  Accuracy(train/val): 46.26%/47.73%  Loss(train/val): 1.50/1.45  Took 28.40 sec
# Epoch   3  Accuracy(train/val): 50.65%/49.20%  Loss(train/val): 1.38/1.43  Took 28.57 sec
# Epoch   4  Accuracy(train/val): 53.52%/51.12%  Loss(train/val): 1.30/1.39  Took 29.34 sec
# Epoch   5  Accuracy(train/val): 56.37%/51.82%  Loss(train/val): 1.22/1.36  Took 28.56 sec
# Epoch   6  Accuracy(train/val): 58.83%/52.91%  Loss(train/val): 1.16/1.36  Took 28.56 sec
# Epoch   7  Accuracy(train/val): 60.46%/52.54%  Loss(train/val): 1.10/1.37  Took 28.63 sec
# Epoch   8  Accuracy(train/val): 62.98%/53.39%  Loss(train/val): 1.03/1.34  Took 28.60 sec
# Epoch   9  Accuracy(train/val): 65.12%/53.63%  Loss(train/val): 0.98/1.35  Took 29.56 sec
# Epoch  10  Accuracy(train/val): 66.97%/54.37%  Loss(train/val): 0.93/1.36  Took 28.52 sec
# ------------------------------------------------------------
# Test Accuracy: 53.890%   Train Loss: 0.92534  Val Loss: 1.36169
# ------------------------------------------------------------
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=300, in_dim=3072, l2=1e-05, lr=0.001, n_layer=5, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 34.82%/42.27%  Loss(train/val): 1.82/1.59  Took 17.53 sec
# Epoch   2  Accuracy(train/val): 43.82%/46.75%  Loss(train/val): 1.57/1.49  Took 17.50 sec
# Epoch   3  Accuracy(train/val): 48.23%/48.67%  Loss(train/val): 1.46/1.45  Took 17.54 sec
# Epoch   4  Accuracy(train/val): 50.46%/49.92%  Loss(train/val): 1.39/1.41  Took 17.61 sec
# Epoch   5  Accuracy(train/val): 53.68%/51.79%  Loss(train/val): 1.30/1.36  Took 17.53 sec
# Epoch   6  Accuracy(train/val): 55.79%/51.93%  Loss(train/val): 1.25/1.35  Took 17.61 sec
# Epoch   7  Accuracy(train/val): 57.23%/52.39%  Loss(train/val): 1.20/1.35  Took 18.63 sec
# Epoch   8  Accuracy(train/val): 59.49%/51.46%  Loss(train/val): 1.15/1.38  Took 17.67 sec
# Epoch   9  Accuracy(train/val): 60.60%/53.58%  Loss(train/val): 1.10/1.35  Took 17.65 sec
# Epoch  10  Accuracy(train/val): 62.27%/53.28%  Loss(train/val): 1.07/1.37  Took 17.54 sec
# ------------------------------------------------------------
# Test Accuracy: 53.040%   Train Loss: 1.06683  Val Loss: 1.36550
# ------------------------------------------------------------
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=500, in_dim=3072, l2=1e-05, lr=0.001, n_layer=5, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 34.80%/42.73%  Loss(train/val): 1.81/1.58  Took 23.92 sec
# Epoch   2  Accuracy(train/val): 44.57%/47.13%  Loss(train/val): 1.54/1.47  Took 23.72 sec
# Epoch   3  Accuracy(train/val): 48.96%/49.23%  Loss(train/val): 1.42/1.42  Took 23.92 sec
# Epoch   4  Accuracy(train/val): 52.11%/50.15%  Loss(train/val): 1.34/1.40  Took 24.79 sec
# Epoch   5  Accuracy(train/val): 54.70%/52.22%  Loss(train/val): 1.26/1.35  Took 23.75 sec
# Epoch   6  Accuracy(train/val): 56.94%/52.92%  Loss(train/val): 1.20/1.34  Took 23.77 sec
# Epoch   7  Accuracy(train/val): 58.87%/52.77%  Loss(train/val): 1.15/1.35  Took 23.63 sec
# Epoch   8  Accuracy(train/val): 60.99%/53.85%  Loss(train/val): 1.09/1.34  Took 23.74 sec
# Epoch   9  Accuracy(train/val): 63.08%/53.42%  Loss(train/val): 1.04/1.35  Took 23.58 sec
# Epoch  10  Accuracy(train/val): 64.64%/53.84%  Loss(train/val): 1.00/1.37  Took 24.67 sec
# ------------------------------------------------------------
# Test Accuracy: 53.060%   Train Loss: 0.99539  Val Loss: 1.36837
# ------------------------------------------------------------
# Namespace(act='relu', device='cpu', dropout=0.2, epoch=10, hid_dim=700, in_dim=3072, l2=1e-05, lr=0.001, n_layer=5, optim='Adam', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch   1  Accuracy(train/val): 35.57%/43.01%  Loss(train/val): 1.80/1.61  Took 31.39 sec
# Epoch   2  Accuracy(train/val): 45.45%/46.37%  Loss(train/val): 1.53/1.50  Took 31.58 sec
# Epoch   3  Accuracy(train/val): 49.43%/48.92%  Loss(train/val): 1.41/1.45  Took 31.61 sec
# Epoch   4  Accuracy(train/val): 52.69%/50.50%  Loss(train/val): 1.33/1.39  Took 31.58 sec
# Epoch   5  Accuracy(train/val): 55.49%/52.75%  Loss(train/val): 1.25/1.33  Took 32.53 sec
# Epoch   6  Accuracy(train/val): 57.44%/52.53%  Loss(train/val): 1.19/1.34  Took 31.77 sec
# Epoch   7  Accuracy(train/val): 59.40%/52.96%  Loss(train/val): 1.13/1.36  Took 31.49 sec
# Epoch   8  Accuracy(train/val): 61.64%/53.85%  Loss(train/val): 1.07/1.33  Took 31.59 sec
# Epoch   9  Accuracy(train/val): 63.20%/53.25%  Loss(train/val): 1.03/1.36  Took 32.37 sec
# Epoch  10  Accuracy(train/val): 64.99%/53.21%  Loss(train/val): 0.98/1.39  Took 31.58 sec
# ------------------------------------------------------------
# Test Accuracy: 53.160%   Train Loss: 0.98490  Val Loss: 1.39311
# ------------------------------------------------------------

# %% [markdown]
# ### Experiment
